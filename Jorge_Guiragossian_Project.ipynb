# %% [markdown]
# <a href="https://colab.research.google.com/github/jorgeguiragossian/Syracuse---IST707/blob/main/Jorge_Guiragossian_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # **Introduction**
# ---
# - Objective
# - Hypothesis

# %% [markdown]
# ---
# # **Stakeholders**
# ---

# %% [markdown]
# ---
# # **Dataset**
# ---
# - Provenance and Reliability

# %% [markdown]
# ---
# # **Exploratory Data Analysis**
# ---

# %% [markdown]
# ---
# # **Clustering Techniques**
# ---
#
# - Scalers
# - Imputers
# - Clustering

# %% [markdown]
# ---
# # **Hyperparameter Tuning**
# ---
